# %% [markdown]
# Paquetes necesarios

# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Inicializaciones

# %%
#Dimensiones de la imagen a crear
ancho = 200
alto = 300

# %% [markdown]
# Imagen en grises

# %%
#Crea una imagen de un único plano, que se interpreta como nivel de gris (0 negro, 255 blanco)
gris_img = np.zeros((ancho,alto,1), dtype = np.uint8)
#Muestra dimensiones de la imagen creada
print(gris_img.shape)
# Out:
# (200, 300, 1)

# %% [markdown]
# Muestra imagen con imshow (OpenCV) en ventana independiente

# %%
#Muestra la imagen (negra al inicializarse a 0) con las utilidades de OpenCV en una ventana independiente
cv2.imshow('Imagen', gris_img)
cv2.imshow('Imagen2', gris_img)

cv2.waitKey(-1) # Se detiene hasta pulsar tecla (>0 milisegundos)
cv2.destroyAllWindows() # Destruye todas las ventanas

# %% [markdown]
# Muestra imagen con matplotlib

# %%
#Muestra la imagen con matplotlib, aparece integrada en el cuaderno
#Es necesario especificar que el mapa de color usado es de grises
#plt.imshow(gris_img, cmap='gray')
#plt.imshow(gris_img)
#plt.show()

#replicar una imagen de gris creando una imagen gris pero con tres planos (RGB)
img2 = cv2.merge((gris_img,gris_img,gris_img))
plt.imshow(img2)
plt.show()

# %%
#Modifica un par de zonas rectangulares de la imagen
gris_img[:] = 0
gris_img[10:20,0:20,0] = 255 #Especifica el canal 0
gris_img[110:220,0:20,0] = 28 #
#gris_img[50:70,40:60] = 255 #realmente no es necesario con un único plano

#Muestra la imagen con matplotlib
#Es necesario especificar que el mapa de color usado es de grises
plt.imshow(gris_img, cmap='gray')
plt.show()

# %% [markdown]
# Imagen con tono de gris aleatorio

# %%
#Crea imagen con un único plano (gris)
gris_img = np.random.randint(255, size=(ancho,alto, 1))
#Muestra dimensiones
print(gris_img.shape)
#Visualiza
plt.imshow(gris_img, cmap='gray') #Visualiza con mapa de color gris
plt.show()
# Out:
# (200, 300, 1)

# %% [markdown]
# Asignamos valor a los píxeles de una zona concreta

# %%
#Modifica la primera mitad de la imagen, asignando 255, es decir blanco
gris_img[0:int(alto/2),:,:] = 255
#Visualiza con mapa de color gris
plt.imshow(gris_img, cmap='gray') #Te animo a probar a eliminar la especificación del mapa de color
plt.show()

# %% [markdown]
# TAREA: Crea una imagen, p.e. 800x800, con la textura del tablero de ajedrez

# %%
color_img = np.zeros((8,8,3), dtype = np.uint8)

color_img[::2,::2] = 255
color_img[1::2,1::2] = 255
#Dimensiones
print(color_img.shape)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()

# %% [markdown]
# Imagen en color

# %%
#Crea una imagen con tres planos
color_img = np.zeros((200,200,3), dtype = np.uint8)
#Dimensiones
print(color_img.shape)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()
# Out:
# (200, 200, 3)

# %%
#Modifica el primer plano de color (Rojo, ya que es RGB)
color_img[:,:,0] = 255 
#color_img[:,:,1] = 200 #Prueba otras combinaciones
#color_img[:,:,2] = 255 
plt.imshow(color_img) 
plt.show()

# %% [markdown]
# TAREA: Crear una imagen estilo Mondrian (un ejemplo https://www3.gobiernodecanarias.org/medusa/ecoescuela/sa/2017/04/17/descubriendo-a-mondrian/ )

# %%
#Crea una imagen con tres planos
color_img = np.zeros((200,200,3), dtype = np.uint8)
#rectangulo laterales blancos
color_img[:57,:50]= color_img[65:145,0:50] = 255
#rectangulo abajo
color_img[150:200,55:175] = 255
#chiquito blanco
color_img[150:175,180:200] = 255
#cuadrado amarillo
color_img[180:200,180:200,1] = color_img[180:200,180:200,0]= 255
#cuadrado rojo
color_img[0:145,55:200,0] = 255
#cuadrado azul
color_img[150:200,0:50,2]= 255
plt.imshow(color_img) 
plt.show()


#Salva la imagen resultante a disco
cv2.imwrite('imagen.jpg', color_img)

# %% [markdown]
# Funciones de dibujo.
# OpenCV dispone de distintas funciones específicas para dibujar formas básicas (más información https://docs.opencv.org/4.x/dc/da5/tutorial_py_drawing_functions.html )

# %%
#Crea una imagen con tres planos
color_img = np.zeros((200,200,3), dtype = np.uint8)

"""
#Línea roja vertical de grosor 3
cv2.line(color_img,(int(ancho/2),0),(int(ancho/2),alto),(255,0,0),3)
#Rectángulo con grosor 2
cv2.rectangle(color_img,(10,10),(ancho-10,int(alto/2)),(0,255,0),2)
#Rectángulo relleno
cv2.rectangle(color_img,(20,20),(60,40),(0,255,0),-1)
#Círculo de radio 15 relleno
cv2.circle(color_img,(ancho-60,30), 15, (0,0,255), -1)
#Visualiza sin especificar el mapa de color gris
plt.imshow(color_img) 
plt.show()
"""
#Creación del tablero de ajedrez, como tenemos un plano de 200*200 y el ajedrez tiene 4 cuadrículas de cada color 
#por cada eje, tendremos cuadrados de 50*50

for ejeY in range (0, 200, 50):
    for ejeX in range (0, 200, 50):
        cv2.rectangle(color_img,(ejeX,ejeY),(ejeX + 25, ejeY + 25),(255,255,255),-2)
        cv2.rectangle(color_img,(ejeX + 25, ejeY + 25),(ejeX+50, ejeY+50),(255,255,255),-2)


plt.imshow(color_img) 
plt.show()
#Salva la imagen resultante a disco
cv2.imwrite('imagen.jpg', color_img)
# Out:
# True

# %% [markdown]
# TAREA: Resuelve una de las tareas previas (a elegir) con las funciones de dibujo de OpenCV  :)

# %%
color_img = np.zeros((200,200,3), dtype = np.uint8)

cv2.rectangle(color_img,(0,np.random.randint(0,50)),(50,np.random.randint(20,50)),(255,0,255),-1)
cv2.rectangle(color_img,(0,np.random.randint(50,90)),(50,np.random.randint(60,100)),(255,255,0),-1)
cv2.rectangle(color_img,(0,np.random.randint(100,130)),(50,np.random.randint(110,200)),(0,255,255),-1)

cv2.rectangle(color_img,(np.random.randint(55,75),0),(np.random.randint(175,200),np.random.randint(100,150)),(0,255,0),-1)

cv2.rectangle(color_img,(np.random.randint(60,80),np.random.randint(155,160)),(np.random.randint(110,150),np.random.randint(180,200)),(255,0,0),-1)
cv2.rectangle(color_img,(np.random.randint(160,180),np.random.randint(155,160)),(np.random.randint(180,200),np.random.randint(180,200)),(255,255,255),-1)
plt.imshow(color_img) 
plt.show()


#Salva la imagen resultante a disco
cv2.imwrite('imagen.jpg', color_img)

# %% [markdown]
# Abrir imagen almacenada en disco

# %%
#Carga imagen desde disco
img = cv2.imread('logo_ulpgc_vertical_acronimo_mancheta_azul.png') 
#Dimensiones
print(img.shape)
#Muestra
plt.imshow(img) 
plt.show()

#OpenCV lee las imágenes de disco en formato BGR, por lo que convertimos para visualizr RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb) 
plt.show()

#Fuerza lectura en grises
img = cv2.imread('logo_ulpgc_vertical_acronimo_mancheta_azul.png', cv2.IMREAD_GRAYSCALE) 
plt.imshow(img, cmap='gray') 
plt.show()
# Out:
# (1200, 1180, 3)

# %% [markdown]
# Abre un archivo de vídeo

# %%
vid = cv2.VideoCapture('Ayagaures_vibe_result.mp4') #Busca n vídeo propio
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:  
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(1000) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ganma\Documents\VC\Practica_1\VC_P1.ipynb Cell 27 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/ganma/Documents/VC/Practica_1/VC_P1.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a>         cv2.imshow('Vid', frame)
#      <a href='vscode-notebook-cell:/c%3A/Users/ganma/Documents/VC/Practica_1/VC_P1.ipynb#X35sZmlsZQ%3D%3D?line=10'>11</a>     # Detenemos pulsado ESC
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ganma/Documents/VC/Practica_1/VC_P1.ipynb#X35sZmlsZQ%3D%3D?line=11'>12</a>     if cv2.waitKey(1000) == 27:
#      <a href='vscode-notebook-cell:/c%3A/Users/ganma/Documents/VC/Practica_1/VC_P1.ipynb#X35sZmlsZQ%3D%3D?line=12'>13</a>         break
#      <a href='vscode-notebook-cell:/c%3A/Users/ganma/Documents/VC/Practica_1/VC_P1.ipynb#X35sZmlsZQ%3D%3D?line=14'>15</a> # Libera el objeto de captura
#
# KeyboardInterrupt:

# %% [markdown]
# Muestra entrada de la cámara

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()
  
    if ret:  
        # Muestra fotograma
        cv2.imshow('Vid', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Separa los tres planos de la imagen captada por la webcam

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Separamos canales
        b = frame[:,:,0]
        g = frame[:,:,1]
        r = frame[:,:,2]
        #Dimensiones
        h, w, c = frame.shape

        #Concateamos en horizontal los tres planos del fotograma
        collage = np.hstack((r, g, b))
    
        # Muestra fotograma redimensionando a la mitad para que quepa en pantalla
        cv2.imshow('Cam3', cv2.resize(collage, (int(w*1.5),int(h/2)),cv2.INTER_NEAREST))
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Modifica de alguna forma los valores de un plano de la imagen

# %%
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Separamos canales
        b = frame[:,:,0]
        g = frame[:,:,1]
        r = frame[:,:,2]
        #Dimensiones
        b_mod = b + 75
        g_mod = g + 75
        r_mod = r + 75
        #Concateamos en horizontal los tres planos del fotograma
        frame_modificado_b = cv2.merge((b_mod, g, r))
        frame_modificado_g = cv2.merge((b, g_mod, r))
        frame_modificado_r = cv2.merge((b, g, r_mod))
    
        # Muestra fotograma redimensionando a la mitad para que quepa en pantalla
        collage = np.hstack((frame, frame_modificado_b,frame_modificado_g,frame_modificado_r))
        cv2.imshow('Coso',collage)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Evento de ratón para mostrar el valor RGB del píxel

# %%
# Función que trata eventos de ratón 
def mouse_events(event, x, y, flags, params):
    global px, py, R, G, B
    px = -1
    # Movimiento del puntero     
    if event==cv2.EVENT_MOUSEMOVE:
        #Valores del píxel
        B = frame[y, x, 0]
        G = frame[y, x, 1]
        R = frame[y, x, 2]  

        px = x
        py = y

# %%
vid = cv2.VideoCapture(0)

# Tipografía para mostrar texto
font = cv2.FONT_HERSHEY_SIMPLEX
  
lanzado = 0
px = -1
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret: 
        # Activa em manejador en el primer fotograma
        if lanzado == 0:
            # Muestra fotograma
            cv2.imshow('Cam', frame)   
            # Define el nombre del manejador del evento
            cv2.setMouseCallback('Cam', mouse_events)
            lanzado = 1
            
        # Muestra valores RGB intentando centrar en el puntero
        if px > -1:
            cv2.putText(frame, '{}'.format(R), (px-45,py-5), font, 0.5, (0, 0, 255), 1)
            cv2.putText(frame, '     {}'.format(G), (px-54,py-5), font, 0.5, (0, 255, 0), 1)
            cv2.putText(frame, '         {}'.format(B), (px-54,py-5), font, 0.5, (255, 0, 0), 1)
            
        cv2.imshow('Cam', frame)   
        
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA:
# Pintar círculos en las posiciones del píxel más claro y oscuro de la imagen
# ¿Si quisieras hacerlo sobre la zona 8x8 más clara/oscura?

# %%
vid = cv2.VideoCapture(0)

ncells = 10
off = int(ncells/2)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Dimensiones originales
        h, w, c = frame.shape
        #Dimensiones reducidas

        # Creamos imagen negra
        frame_gris = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        pixel_mas_claro = 0,0
        pixel_mas_oscuro = 0,0

        valor_pixel_mas_claro = 155 # Inicializa el valor del píxel más claro
        valor_pixel_mas_oscuro = 155

        radio = 10
        color_verde = (0, 255, 0)
        color_rojo = (0, 0, 255)
        grosor = 2

        
        for y in range(0,h):
            for x in range(0,w):
                valor_pixel = frame_gris[y, x]
                
                # Compara el valor del píxel actual con el más claro y el más oscuro
                if valor_pixel > valor_pixel_mas_claro:
                    valor_pixel_mas_claro = valor_pixel
                    coordenadas_pixel_mas_claro = (x, y)
                if valor_pixel < valor_pixel_mas_oscuro:
                    valor_pixel_mas_oscuro = valor_pixel
                    coordenadas_pixel_mas_oscuro = (x, y)

        cv2.circle(frame, (coordenadas_pixel_mas_claro[0], coordenadas_pixel_mas_claro[1]), radio, color_verde, grosor)
        cv2.circle(frame, (coordenadas_pixel_mas_oscuro[0], coordenadas_pixel_mas_oscuro[1]), radio, color_rojo, grosor)


        print("==============SEGUN EL BUCLE==============")
        print(f'Coordenadas del píxel más claro: {coordenadas_pixel_mas_claro}')
        print(f'Valor del píxel más claro: {valor_pixel_mas_claro}')

        print(f'Coordenadas del píxel más oscuro: {coordenadas_pixel_mas_oscuro}')
        print(f'Valor del píxel más oscuro: {valor_pixel_mas_oscuro}')
        
        cv2.imshow('Cam', frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Pop art
# Salida de la webcam "inspirada" en Andy Warhol

# %%
vid = cv2.VideoCapture(0)

#Dimensiones de la cámara
w = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))

#Fuerzo a mitad de resolución para ocupar menos pantalla
w=int(w/2)
h=int(h/2)
vid.set(cv2.CAP_PROP_FRAME_WIDTH, w) #En Mac no reacciona a estos comandos
vid.set(cv2.CAP_PROP_FRAME_HEIGHT, h)

#Imagen conjunta 2x original
collage = np.zeros((h*2,w*2,3), dtype = np.uint8)
tl = collage[0:h,0:w]
tr = collage[0:h,w:w+w]
bl = collage[h:h+h,0:w]
br = collage[h:h+h,w:w+w]

while True:      
    # fotograma a fotograma
    ret, frameIN = vid.read()

    #Menor tamaño
    frame = cv2.resize(frameIN, (int(w),int(h)),cv2.INTER_NEAREST)

    if ret:
        #Separamos canales
        r = frame[:,:,2]
        g = frame[:,:,1]
        b = frame[:,:,0]

        #Jugamos
        tl[:,:,0] = b
        tl[:,:,1] = g
        tl[:,:,2] = r

        tr[:,:,0] = 255 - r
        tr[:,:,1] = g
        tr[:,:,2] = b
        
        bl[:,:,0] = r
        bl[:,:,1] = 255 - b
        bl[:,:,2] = g

        br[:,:,0] = b
        br[:,:,1] = g
        br[:,:,2] = 255 - r
    
        # Muestra composicion
        cv2.imshow('Cam', collage)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# Transformando la imagen capturada en una colección de círculos, cuyo radio depende de la intensidad promedio de la zona

# %%
vid = cv2.VideoCapture(0)

ncells = 10
off = int(ncells/2)
  
while(True):      
    # fotograma a fotograma
    ret, frame = vid.read()

    if ret:
        #Dimensiones originales
        h, w, c = frame.shape
        #Redimensiono
        down_frame = cv2.resize(frame, (int(w/ncells),int(h/ncells)),cv2.INTER_NEAREST)
        #Dimensiones reducidas
        h2, w2, c2 = down_frame.shape

        #Separamos canales
        r = down_frame[:,:,0]
        g = down_frame[:,:,1]
        b = down_frame[:,:,2]

        # Creamos imagen negra
        gris_up_frame = np.zeros((h2*ncells,w2*ncells,1), dtype = np.uint8)

        for y in range(0,h2):
            for x in range(0,w2):
                # La suma de los valores RGB define el radio del círculo
                rad = int ( (r[y,x] + g[y,x] + b[y,x])/(ncells*3*2))
                cv2.circle(gris_up_frame,(x*ncells+off, y*ncells + off), rad, (255,255,255), -1)

    
        # Muestra fotograma resultante
        cv2.imshow('Cam', gris_up_frame)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()

# %% [markdown]
# TAREA: Haz tu propuesta pop art
